# %% [markdown]
# ![Data Seekho Google Form Background (3).png](data:image/png;base64,...)

# %% [markdown]
# # Hi, I'm Anosha 👋
#
# Welcome to my GitHub profile! I'm currently a **Machine Learning Bootcamp Fellow** at [Data Seekho](https://dataseekho.com), where I'm honing my expertise in machine learning, data science, and artificial intelligence. I am driven by a passion for solving real-world challenges through data-driven solutions and am committed to deepening my knowledge and skills in this dynamic field.
#
#
# ---
#
# ## 🌟 About Me
# - 🎓 **Education**: Bachelor’s in Computer Science from Sukkur IBA University Mirpurkhas Campus.
# - 💻 **Skills**: Python, SQL, Machine Learning, Data Visualization, Pandas, NumPy, Scikit-Learn, TensorFlow, Matplotlib, Seaborn
# - 🌱 **Currently Learning**: Python, Data Analytics, and Advanced Data Science techniques
# - 🤝 **Looking to collaborate on**: Open-source data science projects and machine learning competitions
# - 🔭 **Research Interests**: Data Science, AI Ethics, Predictive Modeling, Generative AI
# - 📫 **How to reach me**: anoshaahmed72@gmail.com | www.linkedin.com/in/anosha-sadia-92585124a

# %% [markdown]
# # ***Predicting Heart Disease using Machine Learning***

# %% [markdown]
# # **PREPROCESSING**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart_dataset.csv")

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %% [markdown]
# **Step 1: Check for missing values**

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# **Step 2 Check for Outliers**

# %%
df['chol'].plot(kind='box')
plt.show()

# %%
df['thalach'].plot(kind='box')
plt.show()

# %%
df['trestbps'].plot(kind='box')
plt.show()

# %%
df['oldpeak'].plot(kind='box')
plt.show()

# %% [markdown]
# **Chol**

# %%
Q1 = df['chol'].quantile(0.25)
Q3 = df['chol'].quantile(0.75)
IQR = Q3-Q1

lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR

df_no_outliers = df[(df['chol'] >= lower_bound) & (df['chol'] <= upper_bound)]

# %%
plt.figure(figsize=(8,4))

plt.subplot(1, 2, 1)
plt.boxplot(df['chol'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title('Original Data')

plt.subplot(1, 2, 2)
plt.boxplot(df_no_outliers['chol'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
Q1 = df['chol'].quantile(0.25)
Q3 = df['chol'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df[(df['chol'] >= lower_bound) & (df['chol'] <= upper_bound)]

plt.figure(figsize=(8, 5))
plt.boxplot(df_no_outliers['chol'], vert=False)
plt.title('chol (After Removing Outliers)')
plt.xlabel('chol')
plt.show()

# %% [markdown]
# **Thalach**

# %%
Q1 = df['thalach'].quantile(0.25)
Q3 = df['thalach'].quantile(0.75)
IQR = Q3-Q1

lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR

df_no_outliers = df[(df['thalach'] >= lower_bound) & (df['thalach'] <= upper_bound)]
plt.figure(figsize=(8,4))

plt.subplot(1, 2, 1)
plt.boxplot(df['thalach'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title('Original Data')

plt.subplot(1, 2, 2)
plt.boxplot(df_no_outliers['thalach'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
Q1 = df['thalach'].quantile(0.25)
Q3 = df['thalach'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df[(df['thalach'] >= lower_bound) & (df['thalach'] <= upper_bound)]

plt.figure(figsize=(8, 5))
plt.boxplot(df_no_outliers['thalach'], vert=False)
plt.title('thalach (After Removing Outliers)')
plt.xlabel('thalach')
plt.show()

# %% [markdown]
# **Trestbps**

# %%
Q1 = df['trestbps'].quantile(0.25)
Q3 = df['trestbps'].quantile(0.75)
IQR = Q3-Q1

lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR

df_no_outliers = df[(df['trestbps'] >= lower_bound) & (df['trestbps'] <= upper_bound)]
plt.figure(figsize=(8,4))

plt.subplot(1, 2, 1)
plt.boxplot(df['trestbps'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title('Original Data')

plt.subplot(1, 2, 2)
plt.boxplot(df_no_outliers['trestbps'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
Q1 = df['trestbps'].quantile(0.25)
Q3 = df['trestbps'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df[(df['trestbps'] >= lower_bound) & (df['trestbps'] <= upper_bound)]

plt.figure(figsize=(8, 5))
plt.boxplot(df_no_outliers['trestbps'], vert=False)
plt.title('trestbps (After Removing Outliers)')
plt.xlabel('trestbps')
plt.show()

# %% [markdown]
# **Oldpeak**

# %%
Q1 = df['oldpeak'].quantile(0.25)
Q3 = df['oldpeak'].quantile(0.75)
IQR = Q3-Q1

lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR

df_no_outliers = df[(df['oldpeak'] >= lower_bound) & (df['oldpeak'] <= upper_bound)]
plt.figure(figsize=(8,4))

plt.subplot(1, 2, 1)
plt.boxplot(df['oldpeak'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title('Original Data')

plt.subplot(1, 2, 2)
plt.boxplot(df_no_outliers['oldpeak'], vert=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('Without Outliers')

plt.tight_layout()
plt.show()

# %%
Q1 = df['oldpeak'].quantile(0.25)
Q3 = df['oldpeak'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df[(df['oldpeak'] >= lower_bound) & (df['oldpeak'] <= upper_bound)]

plt.figure(figsize=(8, 5))
plt.boxplot(df_no_outliers['oldpeak'], vert=False)
plt.title('oldpeak (After Removing Outliers)')
plt.xlabel('oldpeak')
plt.show()

# %% [markdown]
# # ***Heart Disease Prediction***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score

import time
print(f"Last updated: {time.asctime()}")
# Out:
# Last updated: Sat Oct 26 19:27:32 2024

# %%
df.shape
# Out:
# (303, 14)

# %%
df.target.value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
df.target.value_counts(normalize=True)
# Out:
# target
# 1    0.544554
# 0    0.455446
# Name: proportion, dtype: float64

# %%
df["target"].value_counts().plot(kind="bar", color=["lightblue", "lightgreen"]);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.sex.value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
pd.crosstab(df.target, df.sex)
# Out:
# sex      0    1
# target
# 0       24  114
# 1       72   93

# %%
# Compare target column with sex column
pd.crosstab(df.target, df.sex)
# Create a plot of crosstab
pd.crosstab(df.target, df.sex).plot(kind="bar",
                                    figsize=(10, 6),
                                    color=["lightblue", "lightgreen"])

plt.title("Heart Disease Frequency for Sex")
plt.xlabel("0 = No Diesease, 1 = Disease")
plt.ylabel("Amount")
plt.legend(["Female", "Male"]);
plt.xticks(rotation=0);

# %%
# Create another figure
plt.figure(figsize=(10,6))
plt.scatter(df.age[df.target==1],
            df.thalach[df.target==1],
            c="lightblue")
plt.scatter(df.age[df.target==0],
            df.thalach[df.target==0],
            c="lightgreen")
plt.title("Heart Disease in function of Age and Max Heart Rate")
plt.xlabel("Age")
plt.legend(["Disease", "No Disease"])
plt.ylabel("Max Heart Rate");

# %% [markdown]
# # **Logistic Regression**

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
X = df.drop("target", axis=1)

y = df["target"]

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %% [markdown]
# **Training and test split**

# %%
np.random.seed(42)
#70% training 30% testing
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3)

# %%
X_train.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 124   39    0   2        94   199    0        1      179      0      0.0
# 72    29    1   1       130   204    0        0      202      0      0.0
# 15    50    0   2       120   219    0        1      158      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 163   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal
# 124      2   0     2
# 72       2   0     2
# 15       1   0     2
# 10       2   0     2
# 163      2   4     2

# %%
y_train, len(y_train)
# Out:
# (124    1
#  72     1
#  15     1
#  10     1
#  163    1
#        ..
#  188    0
#  71     1
#  106    1
#  270    0
#  102    1
#  Name: target, Length: 212, dtype: int64,
#  212)

# %%
X_test.head()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 179   57    1   0       150   276    0        0      112      1      0.6
# 228   59    1   3       170   288    0        0      159      0      0.2
# 111   57    1   2       150   126    1        1      173      0      0.2
# 246   56    0   0       134   409    0        0      150      1      1.9
# 60    71    0   2       110   265    1        0      130      0      0.0
#
#      slope  ca  thal
# 179      1   1     1
# 228      1   0     3
# 111      2   1     3
# 246      1   2     3
# 60       2   1     2

# %%
y_test, len(y_test)
# Out:
# (179    0
#  228    0
#  111    1
#  246    0
#  60     1
#        ..
#  250    0
#  19     1
#  143    1
#  79     1
#  144    1
#  Name: target, Length: 91, dtype: int64,
#  91)

# %%
models = {"Logistic Regression": LogisticRegression()}
def fit_and_score(models, X_train, X_test, y_train, y_test):
    np.random.seed(42)
    model_scores = {}

    for name, model in models.items():
        model.fit(X_train, y_train)
        model_scores[name] = model.score(X_test, y_test)
    return model_scores

# %%
model_scores = fit_and_score(models=models,
                             X_train=X_train,
                             X_test=X_test,
                             y_train=y_train,
                             y_test=y_test)

model_scores
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'Logistic Regression': 0.8131868131868132}

# %% [markdown]
# **Model Accuracy**

# %%
model_compare = pd.DataFrame(model_scores, index=['accuracy'])
model_compare.T.plot.bar();

# %% [markdown]
# **Classification Report**

# %%
# Evaluate the grid search LogisticRegression model
gs_log_reg.score(X_test, y_test)
# Out:
# 0.8131868131868132

# %%
# Confusion matrix
print(confusion_matrix(y_test, y_preds))
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# <ipython-input-557-4b13656dfd56> in <cell line: 2>()
#       1 # Confusion matrix
# ----> 2 print(confusion_matrix(y_test, y_preds))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     201             params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
#     202
# --> 203             validate_parameter_constraints(
#     204                 parameter_constraints, params, caller_name=func.__qualname__
#     205             )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      93                 )
#      94
# ---> 95             raise InvalidParameterError(
#      96                 f"The {param_name!r} parameter of {caller_name} must be"
# ...
